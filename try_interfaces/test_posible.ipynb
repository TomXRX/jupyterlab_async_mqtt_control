# %%
html_my="""
<div class="div">
  <div class="div-2">
    <div class="div-3"></div>
    <div class="div-4"></div>
    <div class="div-5"></div>
    <div class="div-6"></div>
    <div class="div-7"></div>
  </div>
  <div class="div-8">
    <div class="div-9"></div>
    <div class="div-10"></div>
    <div class="div-11"></div>
    <div class="div-12"></div>
    <div class="div-13"></div>
  </div>
  <div class="div-14">
    <div class="div-15"></div>
    <div class="div-16"></div>
    <div class="div-17"></div>
    <div class="div-18"></div>
    <div class="div-19"></div>
  </div>
  <div class="div-20">
    <div class="div-21"></div>
    <div class="div-22"></div>
    <div class="div-23"></div>
    <div class="div-24"></div>
    <div class="div-25"></div>
  </div>
  <div class="div-26">
    <div class="div-27"></div>
    <div class="div-28"></div>
    <div class="div-29"></div>
    <div class="div-30"></div>
    <div class="div-31"></div>
  </div>
</div>
<style>
  .div {
    display: flex;
    flex-direction: row;
    max-width: 175px;
    justify-content: flex-start;
    align-items: flex-start;
    padding-top: 2px;
    padding-bottom: 2px;
    padding-right: 2px;
    padding-left: 2px;
    background-color: rgba(255, 255, 255, 1);
  }
  .div-2 {
    display: flex;
    flex-direction: column;
    max-width: 31px;
    justify-content: flex-start;
    align-items: flex-start;
  }
  .div-3 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    border-radius: 3px;
    background-color: rgba(29, 85, 227, 1);
  }
  .div-4 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(29, 85, 227, 1);
  }
  .div-5 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(29, 85, 227, 1);
  }
  .div-6 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(235, 103, 95, 1);
  }
  .div-7 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(57, 227, 29, 1);
  }
  .div-8 {
    display: flex;
    flex-direction: column;
    max-width: 31px;
    justify-content: flex-start;
    align-items: flex-start;
    margin-left: 4px;
  }
  .div-9 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    border-radius: 3px;
    background-color: rgba(53, 82, 48, 1);
  }
  .div-10 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(53, 82, 48, 1);
  }
  .div-11 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(53, 82, 48, 1);
  }
  .div-12 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(53, 82, 48, 1);
  }
  .div-13 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(53, 82, 48, 1);
  }
  .div-14 {
    display: flex;
    flex-direction: column;
    max-width: 31px;
    justify-content: flex-start;
    align-items: flex-start;
    margin-left: 4px;
  }
  .div-15 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    border-radius: 3px;
    background-color: rgba(53, 82, 48, 1);
  }
  .div-16 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(120, 125, 171, 1);
  }
  .div-17 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(53, 82, 48, 1);
  }
  .div-18 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(120, 125, 171, 1);
  }
  .div-19 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(53, 82, 48, 1);
  }
  .div-20 {
    display: flex;
    flex-direction: column;
    max-width: 31px;
    justify-content: flex-start;
    align-items: flex-start;
    margin-left: 4px;
  }
  .div-21 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    border-radius: 3px;
    background-color: rgba(53, 82, 48, 1);
  }
  .div-22 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(120, 125, 171, 1);
  }
  .div-23 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(53, 82, 48, 1);
  }
  .div-24 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(120, 125, 171, 1);
  }
  .div-25 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(53, 82, 48, 1);
  }
  .div-26 {
    display: flex;
    flex-direction: column;
    max-width: 31px;
    justify-content: flex-start;
    align-items: flex-start;
    margin-left: 4px;
  }
  .div-27 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    border-radius: 3px;
    background-color: rgba(53, 82, 48, 1);
  }
  .div-28 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(53, 82, 48, 1);
  }
  .div-29 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(53, 82, 48, 1);
  }
  .div-30 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(53, 82, 48, 1);
  }
  .div-31 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(53, 82, 48, 1);
  }
</style>
"""

# %%
html_my1="""
<div class="div">
  <div class="div-2">
    <div class="div-3"></div>
    <div class="div-4"></div>
    <div class="div-5"></div>
    <div class="div-6"></div>
    <div class="div-7"></div>
  </div>
  <div class="div-8">
    <div class="div-9"></div>
    <div class="div-10"></div>
    <div class="div-11"></div>
    <div class="div-12"></div>
    <div class="div-13"></div>
  </div>
  <div class="div-14">
    <div class="div-15"></div>
    <div class="div-16"></div>
    <div class="div-17"></div>
    <div class="div-18"></div>
    <div class="div-19"></div>
  </div>
  <div class="div-20">
    <div class="div-21"></div>
    <div class="div-22"></div>
    <div class="div-23"></div>
    <div class="div-24"></div>
    <div class="div-25"></div>
  </div>
  <div class="div-26">
    <div class="div-27"></div>
    <div class="div-28"></div>
    <div class="div-29"></div>
    <div class="div-30"></div>
    <div class="div-31"></div>
  </div>
</div>
<style>
  .div {
    display: flex;
    flex-direction: row;
    max-width: 175px;
    justify-content: flex-start;
    align-items: flex-start;
    padding-top: 2px;
    padding-bottom: 2px;
    padding-right: 2px;
    padding-left: 2px;
    background-color: rgba(255, 255, 255, 1);
  }
  .div-2 {
    display: flex;
    flex-direction: column;
    max-width: 31px;
    justify-content: flex-start;
    align-items: flex-start;
  }
  .div-3 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    border-radius: 3px;
    background-color: rgba(29, 85, 227, 1);
  }
  .div-4 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(29, 85, 227, 1);
  }
  .div-5 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(29, 85, 227, 1);
  }
  .div-6 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(235, 103, 95, 1);
  }
  .div-7 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(57, 227, 29, 1);
  }
  .div-8 {
    display: flex;
    flex-direction: column;
    max-width: 31px;
    justify-content: flex-start;
    align-items: flex-start;
    margin-left: 4px;
  }
  .div-9 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    border-radius: 3px;
    background-color: rgba(255, 255, 0, 1);
  }
  .div-10 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(255, 255, 0, 1);
  }
  .div-11 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(255, 255, 0, 1);
  }
  .div-12 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(255, 255, 0, 1);
  }
  .div-13 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(255, 255, 0, 1);
  }
  .div-14 {
    display: flex;
    flex-direction: column;
    max-width: 31px;
    justify-content: flex-start;
    align-items: flex-start;
    margin-left: 4px;
  }
  .div-15 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    border-radius: 3px;
    background-color: rgba(255, 255, 0, 1);
  }
  .div-16 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(120, 125, 171, 1);
  }
  .div-17 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(255, 255, 0, 1);
  }
  .div-18 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(120, 125, 171, 1);
  }
  .div-19 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(255, 255, 0, 1);
  }
  .div-20 {
    display: flex;
    flex-direction: column;
    max-width: 31px;
    justify-content: flex-start;
    align-items: flex-start;
    margin-left: 4px;
  }
  .div-21 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    border-radius: 3px;
    background-color: rgba(255, 255, 0, 1);
  }
  .div-22 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(120, 125, 171, 1);
  }
  .div-23 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(255, 255, 0, 1);
  }
  .div-24 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(120, 125, 171, 1);
  }
  .div-25 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(255, 255, 0, 1);
  }
  .div-26 {
    display: flex;
    flex-direction: column;
    max-width: 31px;
    justify-content: flex-start;
    align-items: flex-start;
    margin-left: 4px;
  }
  .div-27 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    border-radius: 3px;
    background-color: rgba(255, 255, 0, 1);
  }
  .div-28 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(255, 255, 0, 1);
  }
  .div-29 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(255, 255, 0, 1);
  }
  .div-30 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(255, 255, 0, 1);
  }
  .div-31 {
    display: flex;
    max-width: 31px;
    height: 31px;
    width: 31px;
    margin-top: 4px;
    border-radius: 3px;
    background-color: rgba(255, 255, 0, 1);
  }
</style>
"""

# %%
import sys
import time
from IPython.display import display,HTML,clear_output
for i in range(int(1e10)):
    time.sleep(0.1)
    clear_output(wait=True)
    if i%2:
        display(HTML(html_my))
    else:
        display(HTML(html_my1))
